# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import datetime
import time
import multiprocessing  as mp
from itertools import product

from keras.models import Sequential,Model
from keras.layers import *#Dense, Input, Concatenate, Lambda,LSTM,Dropout,Layer,Flatten
from keras.layers import ConvLSTM2D,BatchNormalization,TimeDistributed,MaxPooling3D
from keras.optimizers import RMSprop, Adam
from keras import optimizers
from keras.utils.vis_utils import plot_model
import keras.losses as kl
import pydot

from keras import optimizers
import keras
import pickle
''
import tensorflow as tf

import sys
import warnings
import os
#from tqdm import tqdm
os.chdir('/gneven/Desktop/ETH/Sem2/Projeckt/Pyhton/')
from scipy.interpolate import UnivariateSpline
from functions import * 

idx = pd.IndexSlice


tf.config.threading.set_intra_op_parallelism_threads(7)
tf.config.threading.set_inter_op_parallelism_threads(7)

# %%
FrameT = pd.read_pickle(os.getcwd()+'/BusFrame32.pickle')
FrameT[np.isnan(FrameT)] = 0
# FrameT[FrameT>400] = 0
# FrameT[FrameT<-400] = 0
np.max(FrameT)

fig = plt.figure()

plt.hist(FrameT.ravel())
# Out:
# (array([2.00000e+00, 1.00000e+00, 1.10000e+01, 2.80000e+01, 5.32101e+05,
#         1.17208e+05, 5.65300e+03, 1.80000e+02, 1.40000e+01, 2.00000e+00]),
#  array([-1677. , -1326.9,  -976.8,  -626.7,  -276.6,    73.5,   423.6,
#           773.7,  1123.8,  1473.9,  1824. ], dtype=float32),
#  <a list of 10 Patch objects>)

# %%
FrameT = pd.read_pickle(os.getcwd()+'/BusFrame32.pickle')

config = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=15, 
                        inter_op_parallelism_threads=15, 
                        allow_soft_placement=True,
                        device_count = {'CPU': 15})

session = tf.compat.v1.Session(config=config)

FrameT[np.isnan(FrameT)] = 0
FrameT[FrameT>400] = 0
FrameT[FrameT<-400] = 0
FrameT = FrameT[:2,:,:,:,:]
meanF = np.mean(FrameT)
FrameT -= meanF
std = np.std(abs(FrameT))
FrameT /= std 

out_dt = 10
in_dt = 30
dt = 30

starttime = 7*3600
endtime = 9*3600

# 6.5 -- 10.5
in_data = [6.5*3600,10.5*3600]

diff = int((starttime- in_data[0])/dt)


input_bus = np.ndarray((FrameT.shape[0],int((endtime-out_dt-starttime)/dt),in_dt,1,FrameT.shape[3],FrameT.shape[4]))#FrameT.shape[2]
output_bus = np.ndarray((FrameT.shape[0],int((endtime-out_dt-starttime)/dt),out_dt,FrameT.shape[3],FrameT.shape[4]))
for i in range(int((endtime-out_dt-starttime)/dt)):
    input_bus[:,i,:,:,:,:] = FrameT[:,(diff+i-in_dt):(diff+i),2:,:,:]
    output_bus[:,i,:,:,:] = FrameT[:,(diff+i):(diff+i+out_dt),2,:,:]
    
vali = input_bus#[[0,6,12,18,24,29,34],:,:,:,:]
valo = output_bus#[[0,6,12,18,24,29,34],:,:,:,:]
input_bus = np.delete(input_bus,[0,6,12,18,24,29,34], axis = 0)
output_bus = np.delete(output_bus,[0,6,12,18,24,29,34], axis = 0)

batch_size =input_bus.shape[1]
print(batch_size)

input_bus = input_bus.reshape(input_bus.shape[0]*input_bus.shape[1],input_bus.shape[2],input_bus.shape[3],input_bus.shape[4],input_bus.shape[5])
output_bus = output_bus.reshape(output_bus.shape[0]*output_bus.shape[1],output_bus.shape[2],output_bus.shape[3],output_bus.shape[4])

vali = vali.reshape(vali.shape[0]*vali.shape[1],vali.shape[2],vali.shape[3],vali.shape[4],vali.shape[5])
valo = valo.reshape(valo.shape[0]*valo.shape[1],valo.shape[2],valo.shape[3],valo.shape[4])

output_bus = np.expand_dims(output_bus,axis = 4)
valo = np.expand_dims(valo,axis = 4)
# Out:
# 239
# /gneven/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:40: DeprecationWarning: in the future out of bounds indices will raise an error instead of being ignored by `numpy.delete`.
# /gneven/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:41: DeprecationWarning: in the future out of bounds indices will raise an error instead of being ignored by `numpy.delete`.

# %%
filter1 = 64
filter2 = 32
kernel1 = 5
kernel2 = 5

epochs = 10

model = Sequential([
    BatchNormalization(name = 'batch_norm_0', input_shape = (in_dt,input_bus.shape[2],input_bus.shape[3],input_bus.shape[4])), 
    
    
    ConvLSTM2D(name ='conv_lstm_1',filters=filter1, kernel_size=(kernel1, 1),stateful=False
                       , padding='same', return_sequences=True,data_format  ="channels_first"),
    Dropout(0.2),
    
    BatchNormalization(),
        
    ConvLSTM2D(name ='conv_lstm_2',filters=filter2, kernel_size=(kernel2, 1),stateful=False
               ,data_format  ="channels_first"
                         ,padding='same', return_sequences=False),
               
    Dropout(0.2),
    
    BatchNormalization(),
    
    
    Flatten(),

    RepeatVector(out_dt),
    
    Reshape((out_dt,output_bus.shape[2],1,filter2)),
 
    
    ConvLSTM2D(name ='conv_lstm_3',filters=filter2,  kernel_size=(kernel2, 1),stateful=False
                        , padding='same', return_sequences=True),
    Dropout(0.1),
    BatchNormalization(),
    
    ConvLSTM2D(name ='conv_lstm_4',
                          filters = filter1, kernel_size = (kernel1, 1),stateful=False, 
                          padding='same',
                          return_sequences = True),
#    Reshape((10,202472)) ,           
#    
#    TimeDistributed(Dense(out.shape[2]*20)),
##    
#    TimeDistributed(Dense(32,)),
#    
    TimeDistributed(Dense(1), name='test'),


    
    
])
# optimizer = optimizers.Adam(clipvalue=0.5)
#optimizer = optimizers.Adam(clipnorm=1.)

model.compile(loss='mean_squared_error', optimizer = 'adam',metrics=['accuracy'])
model.summary()
error = np.array([])


# for e in range(epochs):
#     errorp = 0
#     print('epoque :',e+1)
#     for day in range(FrameT.shape[0] -2):
#         model.fit(input_bus[day,:,:,:,:,:], output_bus[day,:,:,:,:,:], epochs=1,
#                   batch_size=batch_size, verbose=1, shuffle=False)
#         model.reset_states()
#         print('Day :',day+1,', epoch :', e+1)

#     for p in range(1,2):
#         predicty = model.predict(input_bus[-p,:,:,:,:,:])
#         errorp += np.sum(abs(predicty-output_bus[-p,:,:,:,:,:]))
            
#     print('Epoch',e,'Error:',errorp)
        
#     error = np.append(error,errorp)
            
      #,validation_data = (vali,valo)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_norm_0 (BatchNormaliza (None, 30, 1, 13, 1)      4
# _________________________________________________________________
# conv_lstm_1 (ConvLSTM2D)     (None, 30, 64, 13, 1)     83456
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 64, 13, 1)     0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 64, 13, 1)     4
# _________________________________________________________________
# conv_lstm_2 (ConvLSTM2D)     (None, 32, 13, 1)         61568
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32, 13, 1)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 13, 1)         4
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 416)               0
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 10, 416)           0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 10, 13, 1, 32)     0
# _________________________________________________________________
# conv_lstm_3 (ConvLSTM2D)     (None, 10, 13, 1, 32)     41088
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 10, 13, 1, 32)     0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 10, 13, 1, 32)     128
# _________________________________________________________________
# conv_lstm_4 (ConvLSTM2D)     (None, 10, 13, 1, 64)     123136
# _________________________________________________________________
# test (TimeDistributed)       (None, 10, 13, 1, 1)      65
# =================================================================
# Total params: 309,453
# Trainable params: 309,383
# Non-trainable params: 70
# _________________________________________________________________

# %%
predicty = list()
hist = list()
for e in range(100):
    hist.append(model.fit(input_bus, output_bus, epochs=1,
                  batch_size=batch_size, verbose=1, shuffle=False)  )
    
    predicty.append(model.predict(vali[:239,:,:,:,:]))


    
    print('epoch :' ,e, ' over' ) 


    #
# Out:
# Epoch 1/1
# 239/239 [==============================] - 21s 86ms/step - loss: 3.8689 - accuracy: 0.0000e+00
# epoch : 0  over
# Epoch 1/1
# 239/239 [==============================] - 7s 31ms/step - loss: 3.3049 - accuracy: 0.0000e+00
# epoch : 1  over
# Epoch 1/1
# 239/239 [==============================] - 7s 30ms/step - loss: 2.8956 - accuracy: 0.0000e+00
# epoch : 2  over
# Epoch 1/1
# 239/239 [==============================] - 7s 31ms/step - loss: 2.5787 - accuracy: 0.0000e+00
# epoch : 3  over
# Epoch 1/1
# 239/239 [==============================] - 7s 31ms/step - loss: 2.2608 - accuracy: 0.0000e+00
# epoch : 4  over
# Epoch 1/1
# 239/239 [==============================] - 8s 33ms/step - loss: 1.9820 - accuracy: 0.0000e+00
# epoch : 5  over
# Epoch 1/1
# 239/239 [==============================] - 7s 31ms/step - loss: 1.7717 - accuracy: 0.0000e+00
# epoch : 6  over
# Epoch 1/1
# 239/239 [==============================] - 7s 29ms/step - loss: 1.5614 - accuracy: 0.0000e+00
# epoch : 7  over
# Epoch 1/1
# 239/239 [==============================] - 8s 32ms/step - loss: 1.4356 - accuracy: 0.0000e+00
# epoch : 8  over
# Epoch 1/1
# 239/239 [==============================] - 8s 35ms/step - loss: 1.3532 - accuracy: 0.0000e+00
# epoch : 9  over
# Epoch 1/1
# 239/239 [==============================] - 7s 31ms/step - loss: 1.3185 - accuracy: 0.0000e+00
# epoch : 10  over
# Epoch 1/1
# 239/239 [==============================] - 8s 32ms/step - loss: 1.2822 - accuracy: 0.0000e+00
# epoch : 11  over
# Epoch 1/1
# 239/239 [==============================] - 7s 31ms/step - loss: 1.2162 - accuracy: 0.0000e+00
# epoch : 12  over
# Epoch 1/1
# 239/239 [==============================] - 8s 34ms/step - loss: 1.1537 - accuracy: 0.0000e+00
# epoch : 13  over
# Epoch 1/1
# 239/239 [==============================] - 8s 32ms/step - loss: 1.1100 - accuracy: 0.0000e+00
# epoch : 14  over
# Epoch 1/1
# 239/239 [==============================] - 7s 30ms/step - loss: 1.0609 - accuracy: 0.0000e+00
# epoch : 15  over
# Epoch 1/1
# 239/239 [==============================] - 8s 34ms/step - loss: 1.0193 - accuracy: 0.0000e+00
# epoch : 16  over
# Epoch 1/1
# 239/239 [==============================] - 8s 34ms/step - loss: 0.9923 - accuracy: 0.0000e+00
# epoch : 17  over
# Epoch 1/1
# 239/239 [==============================] - 7s 31ms/step - loss: 0.9684 - accuracy: 0.0000e+00
# epoch : 18  over
# Epoch 1/1
# 239/239 [==============================] - 7s 30ms/step - loss: 0.9313 - accuracy: 0.0000e+00
# epoch : 19  over
# Epoch 1/1
# 239/239 [==============================] - 8s 33ms/step - loss: 0.9076 - accuracy: 0.0000e+00
# epoch : 20  over
# Epoch 1/1
# 239/239 [==============================] - 8s 32ms/step - loss: 0.8743 - accuracy: 0.0000e+00
# epoch : 21  over
# Epoch 1/1
# 239/239 [==============================] - 8s 34ms/step - loss: 0.8643 - accuracy: 0.0000e+00
# epoch : 22  over
# Epoch 1/1
# 239/239 [==============================] - 8s 32ms/step - loss: 0.8288 - accuracy: 0.0000e+00
# epoch : 23  over
# Epoch 1/1
# 239/239 [==============================] - 8s 33ms/step - loss: 0.8087 - accuracy: 0.0000e+00
# epoch : 24  over
# Epoch 1/1
# 239/239 [==============================] - 7s 31ms/step - loss: 0.7980 - accuracy: 0.0000e+00
# epoch : 25  over
# Epoch 1/1
# 239/239 [==============================] - 8s 32ms/step - loss: 0.7700 - accuracy: 0.0000e+00
# epoch : 26  over
# Epoch 1/1
# 239/239 [==============================] - 7s 31ms/step - loss: 0.7588 - accuracy: 0.0000e+00
# epoch : 27  over
# Epoch 1/1
# 239/239 [==============================] - 7s 28ms/step - loss: 0.7563 - accuracy: 0.0000e+00
# epoch : 28  over
# Epoch 1/1
# 239/239 [==============================] - 8s 35ms/step - loss: 0.7335 - accuracy: 0.0000e+00
# epoch : 29  over
# Epoch 1/1
# 239/239 [==============================] - 7s 29ms/step - loss: 0.7203 - accuracy: 0.0000e+00
# epoch : 30  over
# Epoch 1/1
# 239/239 [==============================] - 7s 30ms/step - loss: 0.6997 - accuracy: 0.0000e+00
# epoch : 31  over
# Epoch 1/1
# 239/239 [==============================] - 7s 29ms/step - loss: 0.6840 - accuracy: 0.0000e+00
# epoch : 32  over
# Epoch 1/1
# 239/239 [==============================] - 7s 30ms/step - loss: 0.6810 - accuracy: 0.0000e+00
# epoch : 33  over
# Epoch 1/1
# 239/239 [==============================] - 8s 35ms/step - loss: 0.6650 - accuracy: 0.0000e+00
# epoch : 34  over
# Epoch 1/1
# 239/239 [==============================] - 8s 34ms/step - loss: 0.6466 - accuracy: 0.0000e+00
# epoch : 35  over
# Epoch 1/1
# 239/239 [==============================] - 8s 32ms/step - loss: 0.6344 - accuracy: 0.0000e+00
# epoch : 36  over
# Epoch 1/1
# 239/239 [==============================] - 8s 33ms/step - loss: 0.6352 - accuracy: 0.0000e+00
# epoch : 37  over
# Epoch 1/1
# 239/239 [==============================] - 7s 31ms/step - loss: 0.6224 - accuracy: 0.0000e+00
# epoch : 38  over
# Epoch 1/1
# 239/239 [==============================] - 8s 33ms/step - loss: 0.6065 - accuracy: 0.0000e+00
# epoch : 39  over
# Epoch 1/1
# 239/239 [==============================] - 7s 30ms/step - loss: 0.5976 - accuracy: 0.0000e+00
# epoch : 40  over
# Epoch 1/1
# 239/239 [==============================] - 8s 33ms/step - loss: 0.5931 - accuracy: 0.0000e+00
# epoch : 41  over
# Epoch 1/1
# 239/239 [==============================] - 7s 30ms/step - loss: 0.5797 - accuracy: 0.0000e+00
# epoch : 42  over
# Epoch 1/1
# 239/239 [==============================] - 8s 34ms/step - loss: 0.5637 - accuracy: 0.0000e+00
# epoch : 43  over
# Epoch 1/1
# 239/239 [==============================] - 8s 35ms/step - loss: 0.5517 - accuracy: 0.0000e+00
# epoch : 44  over
# Epoch 1/1
# 239/239 [==============================] - 7s 31ms/step - loss: 0.5520 - accuracy: 0.0000e+00
# epoch : 45  over
# Epoch 1/1
# 239/239 [==============================] - 8s 33ms/step - loss: 0.5441 - accuracy: 0.0000e+00
# epoch : 46  over
# Epoch 1/1
# 239/239 [==============================] - 8s 32ms/step - loss: 0.5352 - accuracy: 0.0000e+00
# epoch : 47  over
# Epoch 1/1
# 239/239 [==============================] - 8s 34ms/step - loss: 0.5289 - accuracy: 0.0000e+00
# epoch : 48  over
# Epoch 1/1
# 239/239 [==============================] - 8s 31ms/step - loss: 0.5155 - accuracy: 0.0000e+00
# epoch : 49  over
# Epoch 1/1
# 239/239 [==============================] - 8s 34ms/step - loss: 0.5065 - accuracy: 0.0000e+00
# epoch : 50  over
# Epoch 1/1
# 239/239 [==============================] - 8s 32ms/step - loss: 0.4940 - accuracy: 0.0000e+00
# epoch : 51  over
# Epoch 1/1
# 239/239 [==============================] - 7s 28ms/step - loss: 0.4893 - accuracy: 0.0000e+00
# epoch : 52  over
# Epoch 1/1
# 239/239 [==============================] - 8s 32ms/step - loss: 0.4840 - accuracy: 0.0000e+00
# epoch : 53  over
# Epoch 1/1
# 239/239 [==============================] - 8s 32ms/step - loss: 0.4774 - accuracy: 0.0000e+00
# epoch : 54  over
# Epoch 1/1
# 239/239 [==============================] - 8s 32ms/step - loss: 0.4728 - accuracy: 0.0000e+00
# epoch : 55  over
# Epoch 1/1
# 239/239 [==============================] - 8s 33ms/step - loss: 0.4583 - accuracy: 0.0000e+00
# epoch : 56  over
# Epoch 1/1
# 239/239 [==============================] - 8s 32ms/step - loss: 0.4487 - accuracy: 0.0000e+00
# epoch : 57  over
# Epoch 1/1
# 239/239 [==============================] - 7s 30ms/step - loss: 0.4439 - accuracy: 0.0000e+00
# epoch : 58  over
# Epoch 1/1
# 239/239 [==============================] - 7s 30ms/step - loss: 0.4411 - accuracy: 0.0000e+00
# epoch : 59  over
# Epoch 1/1
# 239/239 [==============================] - 7s 31ms/step - loss: 0.4308 - accuracy: 0.0000e+00
# epoch : 60  over
# Epoch 1/1
# 239/239 [==============================] - 8s 33ms/step - loss: 0.4272 - accuracy: 0.0000e+00
# epoch : 61  over
# Epoch 1/1
# 239/239 [==============================] - 8s 34ms/step - loss: 0.4177 - accuracy: 0.0000e+00
# epoch : 62  over
# Epoch 1/1
# 239/239 [==============================] - 7s 31ms/step - loss: 0.4113 - accuracy: 0.0000e+00
# epoch : 63  over
# Epoch 1/1
# 239/239 [==============================] - 9s 36ms/step - loss: 0.4012 - accuracy: 0.0000e+00
# epoch : 64  over
# Epoch 1/1
# 239/239 [==============================] - 7s 30ms/step - loss: 0.4054 - accuracy: 0.0000e+00
# epoch : 65  over
# Epoch 1/1
# 239/239 [==============================] - 8s 34ms/step - loss: 0.3963 - accuracy: 0.0000e+00
# epoch : 66  over
# Epoch 1/1
# 239/239 [==============================] - 8s 32ms/step - loss: 0.3882 - accuracy: 0.0000e+00
# epoch : 67  over
# Epoch 1/1
# 239/239 [==============================] - 8s 32ms/step - loss: 0.3795 - accuracy: 0.0000e+00
# epoch : 68  over
# Epoch 1/1
# 239/239 [==============================] - 8s 32ms/step - loss: 0.3720 - accuracy: 0.0000e+00
# epoch : 69  over
# Epoch 1/1
# 239/239 [==============================] - 7s 28ms/step - loss: 0.3662 - accuracy: 0.0000e+00
# epoch : 70  over
# Epoch 1/1
# 239/239 [==============================] - 7s 29ms/step - loss: 0.3657 - accuracy: 0.0000e+00
# epoch : 71  over
# Epoch 1/1
# 239/239 [==============================] - 7s 29ms/step - loss: 0.3623 - accuracy: 0.0000e+00
# epoch : 72  over
# Epoch 1/1
# 239/239 [==============================] - 8s 34ms/step - loss: 0.3583 - accuracy: 0.0000e+00
# epoch : 73  over
# Epoch 1/1
# 239/239 [==============================] - 7s 31ms/step - loss: 0.3498 - accuracy: 0.0000e+00
# epoch : 74  over
# Epoch 1/1
# 239/239 [==============================] - 8s 31ms/step - loss: 0.3518 - accuracy: 0.0000e+00
# epoch : 75  over
# Epoch 1/1
# 239/239 [==============================] - 8s 33ms/step - loss: 0.3417 - accuracy: 0.0000e+00
# epoch : 76  over
# Epoch 1/1
# 239/239 [==============================] - 8s 33ms/step - loss: 0.3407 - accuracy: 0.0000e+00
# epoch : 77  over
# Epoch 1/1
# 239/239 [==============================] - 7s 30ms/step - loss: 0.3390 - accuracy: 0.0000e+00
# epoch : 78  over
# Epoch 1/1
# 239/239 [==============================] - 7s 31ms/step - loss: 0.3392 - accuracy: 0.0000e+00
# epoch : 79  over
# Epoch 1/1
# 239/239 [==============================] - 8s 32ms/step - loss: 0.3318 - accuracy: 0.0000e+00
# epoch : 80  over
# Epoch 1/1
# 239/239 [==============================] - 7s 30ms/step - loss: 0.3202 - accuracy: 0.0000e+00
# epoch : 81  over
# Epoch 1/1
# 239/239 [==============================] - 7s 29ms/step - loss: 0.3247 - accuracy: 0.0000e+00
# epoch : 82  over
# Epoch 1/1
# 239/239 [==============================] - 7s 28ms/step - loss: 0.3254 - accuracy: 0.0000e+00
# epoch : 83  over
# Epoch 1/1
# 239/239 [==============================] - 7s 29ms/step - loss: 0.3051 - accuracy: 0.0000e+00
# epoch : 84  over
# Epoch 1/1
# 239/239 [==============================] - 8s 34ms/step - loss: 0.3078 - accuracy: 0.0000e+00
# epoch : 85  over
# Epoch 1/1
# 239/239 [==============================] - 7s 29ms/step - loss: 0.3012 - accuracy: 0.0000e+00
# epoch : 86  over
# Epoch 1/1
# 239/239 [==============================] - 8s 32ms/step - loss: 0.3004 - accuracy: 0.0000e+00
# epoch : 87  over
# Epoch 1/1
# 239/239 [==============================] - 7s 31ms/step - loss: 0.3045 - accuracy: 0.0000e+00
# epoch : 88  over
# Epoch 1/1
# 239/239 [==============================] - 8s 31ms/step - loss: 0.2965 - accuracy: 0.0000e+00
# epoch : 89  over
# Epoch 1/1
# 239/239 [==============================] - 8s 32ms/step - loss: 0.2917 - accuracy: 0.0000e+00
# epoch : 90  over
# Epoch 1/1
# 239/239 [==============================] - 7s 31ms/step - loss: 0.2858 - accuracy: 0.0000e+00
# epoch : 91  over
# Epoch 1/1
# 239/239 [==============================] - 8s 34ms/step - loss: 0.2818 - accuracy: 0.0000e+00
# epoch : 92  over
# Epoch 1/1
# 239/239 [==============================] - 8s 32ms/step - loss: 0.2787 - accuracy: 0.0000e+00
# epoch : 93  over
# Epoch 1/1
# 239/239 [==============================] - 8s 34ms/step - loss: 0.2813 - accuracy: 0.0000e+00
# epoch : 94  over
# Epoch 1/1
# 239/239 [==============================] - 7s 30ms/step - loss: 0.2739 - accuracy: 0.0000e+00
# epoch : 95  over
# Epoch 1/1
# 239/239 [==============================] - 7s 30ms/step - loss: 0.2772 - accuracy: 0.0000e+00
# epoch : 96  over
# Epoch 1/1
# 239/239 [==============================] - 8s 33ms/step - loss: 0.2690 - accuracy: 0.0000e+00
# epoch : 97  over
# Epoch 1/1
# 239/239 [==============================] - 9s 36ms/step - loss: 0.2678 - accuracy: 0.0000e+00
# epoch : 98  over
# Epoch 1/1
# 239/239 [==============================] - 8s 32ms/step - loss: 0.2636 - accuracy: 0.0000e+00
# epoch : 99  over

# %%
loss = autoencoder_train.history['loss']
val_loss = autoencoder_train.history['val_loss']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5ca69f61f7ee> in <module>
# ----> 1 loss = autoencoder_train.history['loss']
#       2 val_loss = autoencoder_train.history['val_loss']
#
# NameError: name 'autoencoder_train' is not defined

# %%
# %matplotlib notebook
which = 1

fig = plt.figure(3)
ax1 = plt.subplot(3,1,1)
plt.title('Prediction')
ax2 = plt.subplot(3,1,2)
ax3 = plt.subplot(3,1,3)
plt.xlabel('Time from start (7am)[min]')
plt.ylabel('Lateness')
for i in range(0,len(predicty),10):
    ax1.plot(predicty[i][:,1,which,0,0],'*',label = 'Epoch %i' %i)
    ax2.plot(i,hist[i].history['loss'],'v')
    
ax3.plot(predicty[i][:,1,which,0,0]*10,'*',label = 'Epoch %i' %i)

ax3.plot(valo[:239,1,which,0,0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5a01be53a092> in <module>
#       2 which = 1
#       3
# ----> 4 fig = plt.figure(3)
#       5 ax1 = plt.subplot(3,1,1)
#       6 plt.title('Prediction')
#
# NameError: name 'plt' is not defined

# %%
ax3.plot(predicty[i][:,1,which,0,0]*10,'*',label = 'Epoch %i' %i)

ax3.plot(valo[:239,1,which,0,0])

# %%
startTime = 7*3600
endTime = 10*3600
dt = 60

FrameT = np.load('BusFrame32.pickels')

x = np.asarray([*range(startTime,endTime,dt)])
y = FrameT[:,0,0,496]
w = np.isnan(y)
y[w] = 0.
spl = UnivariateSpline(x, y, w=~w)
# %matplotlib notebook
for i in 50:
    spl.set_smoothing_factor(i)
    plt.plot(x, spl(x), lw=1,label = i)
    
plt.plot(x[~w], y[~w], 'r', ms=3)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b93d91a7724c> in <module>
#       3 dt = 60
#       4
# ----> 5 FrameT = np.load('BusFrame32.pickels')
#       6
#       7 x = np.asarray([*range(startTime,endTime,dt)])
#
# NameError: name 'np' is not defined

# %%
stops = get_stops_data()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
allfile = os.listdir('data/data2/Times/')

Data = pd.read_csv('data/data2/Times/'+allfile[0])
Data['datum_nach'] = pd.to_datetime(Data['datum_nach'],format="%d.%m.%y")
Data = Data.loc[Data['datum_nach'].dt.dayofweek < 5,:]

# %%
# Out:
# (1102001, 34)

# %%
Data['kurs'] = 100*Data['linie'] + Data['kurs']
Data = Data[~Data['fw_lang'].str.contains('DEP|Einfahrt|Ausfahrt|GAR')]


# 281423

# %%
# %matplotlib notebook

startTime = 7*3600
endTime = 9*3600
Data = Data[Data['linie'] == 32]
for day in Data['datum_nach'].unique():
    DataP = Data[Data['datum_nach'] == day]
    DataP = DataP[(DataP['soll_ab_von'] < endTime)&(DataP['soll_ab_von'] > startTime)]
    plt.plot(DataP['soll_ab_nach'],DataP['halt_diva_nach'],'*',label = day)
    print(DataP['soll_ab_nach'].shape)
    print()
    
    
plt.legend()  





Data[(Data['kurs'] == 3201 )& (Data['ist_ab_von'] < endTime)&(Data['ist_ab_von'] > startTime)]
# Out:
# <img src="data:image/png;base64,..." width="640">
# (980,)
#
# (980,)
#
# (980,)
#
# (980,)
#
# (980,)
#          linie  richtung betriebsdatum  fahrzeug  kurs  seq_von  \
# 386145      32         1      06.01.20     10452  3201       24
# 386663      32         1      06.01.20     10452  3201       24
# 389199      32         1      07.01.20     10075  3201       24
# 389832      32         1      07.01.20     10075  3201       24
# 392126      32         1      10.01.20     10093  3201       24
# ...        ...       ...           ...       ...   ...      ...
# 1295732     32         2      09.01.20     10075  3201       22
# 1295872     32         2      08.01.20     10082  3201       22
# 1296234     32         2      08.01.20     10082  3201       22
# 1297238     32         2      08.01.20     10082  3201        9
# 1297448     32         2      08.01.20     10082  3201        9
#
#          halt_diva_von  halt_punkt_diva_von halt_kurz_von1 datum_von  ...  \
# 386145            1307                   10           IHAG  06.01.20  ...
# 386663            1307                   10           IHAG  06.01.20  ...
# 389199            1307                   10           IHAG  07.01.20  ...
# 389832            1307                   10           IHAG  07.01.20  ...
# 392126            1307                   10           IHAG  10.01.20  ...
# ...                ...                  ...            ...       ...  ...
# 1295732           1000                   11           GLAU  09.01.20  ...
# 1295872           1000                   11           GLAU  08.01.20  ...
# 1296234           1000                   11           GLAU  08.01.20  ...
# 1297238           1357                   11           KALK  08.01.20  ...
# 1297448           1357                   11           KALK  08.01.20  ...
#
#          fahrweg_id  fw_no  fw_typ  fw_kurz      fw_lang  umlauf_von  \
# 386145       109988      1       1        1  HOLZ - STRV      215519
# 386663       109988      1       1        1  HOLZ - STRV      215519
# 389199       109988      1       1        1  HOLZ - STRV      215519
# 389832       109988      1       1        1  HOLZ - STRV      215519
# 392126       109988      1       1        1  HOLZ - STRV      214896
# ...             ...    ...     ...      ...          ...         ...
# 1295732      115243      2       1        2  STRV - HOLZ      215519
# 1295872      115243      2       1        2  STRV - HOLZ      215519
# 1296234      115243      2       1        2  STRV - HOLZ      215519
# 1297238      115243      2       1        2  STRV - HOLZ      215519
# 1297448      115243      2       1        2  STRV - HOLZ      215519
#
#          halt_id_von halt_id_nach halt_punkt_id_von  halt_punkt_id_nach
# 386145          2807         2836             48161               46028
# 386663          2807         2836             48161               46028
# 389199          2807         2836             48161               46028
# 389832          2807         2836             48161               46028
# 392126          2807         2836             48161               46028
# ...              ...          ...               ...                 ...
# 1295732         2454         2457             44729               44335
# 1295872         2454         2457             44729               44335
# 1296234         2454         2457             44729               44335
# 1297238         1906         2247             49953               42936
# 1297448         1906         2247             49953               42936
#
# [389 rows x 34 columns]

# %%
service_kurs = set([])
DataO = Data[Data['datum_nach'] == Data['datum_nach'].unique()[-1]]
minO = np.inf
for  day in Data['datum_nach'].unique():
    if Data.loc[Data['datum_nach'] == day,'fw_lang'].unique().shape[0] < minO:
        DataO=Data[Data['datum_nach'] == day]   
    
    
for  day in Data['datum_nach'].unique():
    DataP = Data[(Data['datum_nach'] == day)]
    for kurs in DataP['kurs'].unique():
        Datapi = DataP[DataP['kurs'] == kurs]
        transVAr = Datapi.loc[~Datapi['soll_ab_nach'].isin(DataO.loc[DataO['kurs'] == kurs,'soll_ab_nach']),'fw_lang'].values
        for i in range(transVAr.shape[0]) :
            service_kurs.add(transVAr[i])

# %%
allfile = os.listdir('data/data2/Times/')



Data = get_time_data('data/data2/Times/'+allfile[0])

for str in allfile[1:]:
       Data = pd.concat([Data,get_time_data('data/data2/Times/'+str)])
    
Data = Data.loc[Data['datum_nach'].dt.dayofweek < 5,:]
#delete depot run
Data = Data[~Data['fw_lang'].str.contains('DEP|Einfahrt|Ausfahrt')]

Data['Lateness'] = (Data['ist_ab_nach']-Data['soll_ab_nach'])

# %%
fig = plt.figure(10)

ax = fig.gca()

ax.hist(Data['Lateness'])
ax.set(xlabel = 'Latness',ylabel = 'Distribution',title = 'Latness distribution')
ax.set_yscale('log')

test = Data[Data['Lateness']> 1200]

print('there is ',Data[Data['Lateness']> 1200].shape[0]*100/Data.shape[0],'% of lateness higher than 20min')
# Out:
# there is  0.05199615380411645 % of lateness higher than 20min

# %%
fig = plt.figure(11,figsize = (12,6))

ax = fig.gca()

ax.bar(range(len(test['linie'].unique())),test.groupby(['linie']).count()['richtung'])
ax.set(xlabel = 'Line',ylabel = 'Distribution',title = 'Latness distribution')
ax.set_yscale('log')

plt.xticks(range(len(test['linie'].unique())),rotation=90)
ax.set_xticklabels(test.groupby(['linie']).count().index)

fig = plt.figure(12)

ax = fig.gca()

ax.hist(test['Lateness']/60)
ax.set(xlabel = 'Latness [min]',ylabel = 'Distribution',title = 'Latness distribution')
ax.set_yscale('log')

fig = plt.figure(13,figsize = (12,6))

ax = fig.gca()

ax.bar(range(len(test['datum_nach'].unique())),test.groupby(['datum_nach']).count()['richtung'])
ax.set(xlabel = 'Day',ylabel = 'Distribution',title = 'Latness distribution')
ax.set_yscale('log')

plt.xticks(range(len(test['datum_nach'].unique())),rotation=90)
ax.set_xticklabels(test.groupby(['datum_nach']).count().index)
# Out:
# [Text(0, 0, '2020-01-06 00:00:00'),
#  Text(0, 0, '2020-01-07 00:00:00'),
#  Text(0, 0, '2020-01-08 00:00:00'),
#  Text(0, 0, '2020-01-09 00:00:00'),
#  Text(0, 0, '2020-01-10 00:00:00'),
#  Text(0, 0, '2020-01-13 00:00:00'),
#  Text(0, 0, '2020-01-14 00:00:00'),
#  Text(0, 0, '2020-01-15 00:00:00'),
#  Text(0, 0, '2020-01-16 00:00:00'),
#  Text(0, 0, '2020-01-17 00:00:00'),
#  Text(0, 0, '2020-01-20 00:00:00'),
#  Text(0, 0, '2020-01-21 00:00:00'),
#  Text(0, 0, '2020-01-22 00:00:00'),
#  Text(0, 0, '2020-01-23 00:00:00'),
#  Text(0, 0, '2020-01-24 00:00:00'),
#  Text(0, 0, '2020-01-27 00:00:00'),
#  Text(0, 0, '2020-01-28 00:00:00'),
#  Text(0, 0, '2020-01-29 00:00:00'),
#  Text(0, 0, '2020-01-30 00:00:00'),
#  Text(0, 0, '2020-01-31 00:00:00'),
#  Text(0, 0, '2020-02-03 00:00:00'),
#  Text(0, 0, '2020-02-04 00:00:00'),
#  Text(0, 0, '2020-02-05 00:00:00'),
#  Text(0, 0, '2020-02-06 00:00:00'),
#  Text(0, 0, '2020-02-07 00:00:00'),
#  Text(0, 0, '2020-02-10 00:00:00'),
#  Text(0, 0, '2020-02-11 00:00:00'),
#  Text(0, 0, '2020-02-12 00:00:00'),
#  Text(0, 0, '2020-02-13 00:00:00'),
#  Text(0, 0, '2020-02-14 00:00:00'),
#  Text(0, 0, '2020-02-17 00:00:00'),
#  Text(0, 0, '2020-02-18 00:00:00'),
#  Text(0, 0, '2020-02-19 00:00:00'),
#  Text(0, 0, '2020-02-20 00:00:00'),
#  Text(0, 0, '2020-02-21 00:00:00')]

# %%
test.sort_values('Lateness')

test['datum_nach'].unique()
# Out:
# array(['2020-01-10T00:00:00.000000000', '2020-01-08T00:00:00.000000000',
#        '2020-01-06T00:00:00.000000000', '2020-01-07T00:00:00.000000000',
#        '2020-01-09T00:00:00.000000000', '2020-01-17T00:00:00.000000000',
#        '2020-01-14T00:00:00.000000000', '2020-01-16T00:00:00.000000000',
#        '2020-01-15T00:00:00.000000000', '2020-01-13T00:00:00.000000000',
#        '2020-01-22T00:00:00.000000000', '2020-01-21T00:00:00.000000000',
#        '2020-01-20T00:00:00.000000000', '2020-01-23T00:00:00.000000000',
#        '2020-01-24T00:00:00.000000000', '2020-01-29T00:00:00.000000000',
#        '2020-01-28T00:00:00.000000000', '2020-01-30T00:00:00.000000000',
#        '2020-01-31T00:00:00.000000000', '2020-01-27T00:00:00.000000000',
#        '2020-02-05T00:00:00.000000000', '2020-02-03T00:00:00.000000000',
#        '2020-02-07T00:00:00.000000000', '2020-02-04T00:00:00.000000000',
#        '2020-02-06T00:00:00.000000000', '2020-02-11T00:00:00.000000000',
#        '2020-02-14T00:00:00.000000000', '2020-02-13T00:00:00.000000000',
#        '2020-02-12T00:00:00.000000000', '2020-02-10T00:00:00.000000000',
#        '2020-02-18T00:00:00.000000000', '2020-02-19T00:00:00.000000000',
#        '2020-02-17T00:00:00.000000000', '2020-02-21T00:00:00.000000000',
#        '2020-02-20T00:00:00.000000000'], dtype='datetime64[ns]')
